# %%
# %cd /content
import os
from getpass import getpass
import urllib
from google.colab import userdata

user = "jamesweiland"
token = userdata.get("GITHUB_PAT")
token = urllib.parse.quote(token)  # encode token for URL safety
repo = 'jamesweiland/sample-hunter'

cmd = f'git clone -b colab https://{user}:{token}@github.com/{repo}.git'
os.system(cmd)
# Out:
# /content
# 0

# %%
# %cd sample-hunter/
# !uv sync
# Out:
# Streaming output truncated to the last 5000 lines.
# nvidia-nccl-cu12 ------------------------------ 82.05 MiB/191.99 MiB
# nvidia-cusparse-cu12 ------------------------------ 81.88 MiB/206.53 MiB
# nvidia-cublas-cu12 ------------------------------ 81.64 MiB/374.93 MiB
# nvidia-cudnn-cu12 ------------------------------ 81.87 MiB/544.54 MiB
# ⠋ Preparing packages... (107/116)
# triton     ------------------------------ 81.40 MiB/148.46 MiB
# nvidia-cusparselt-cu12 ------------------------------ 82.08 MiB/149.52 MiB
# nvidia-cusolver-cu12 ------------------------------ 81.91 MiB/150.90 MiB
# nvidia-cufft-cu12 ------------------------------ 82.53 MiB/190.95 MiB
# nvidia-nccl-cu12 ------------------------------ 82.19 MiB/191.99 MiB
# nvidia-cusparse-cu12 ------------------------------ 82.18 MiB/206.53 MiB
# nvidia-cublas-cu12 ------------------------------ 81.89 MiB/374.93 MiB
# nvidia-cudnn-cu12 ------------------------------ 82.04 MiB/544.54 MiB
# ⠙ Preparing packages... (107/116)
# ...

# %%
# !uv run python3 -m sample_hunter.pipeline.train --help
# Out:
# usage: train.py [-h] [--out OUT] [--repo-id REPO_ID] [--token TOKEN]
#                 [--tensorboard TENSORBOARD]
#
# options:
#   -h, --help            show this help message and exit
#   --out OUT             The path to save the trained model to
#   --repo-id REPO_ID     The path to the HF dataset
#   --token TOKEN         Your huggingface token
#   --tensorboard TENSORBOARD
#                         The path to the log directory for tensorboard

# %%
# run this if you need to update the code
# !git pull
# Out:
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 11 (delta 9), reused 11 (delta 9), pack-reused 0 (from 0)
# Unpacking objects: 100% (11/11), 1.11 KiB | 378.00 KiB/s, done.
# From https://github.com/jamesweiland/sample-hunter
#    44ceeff..886c6d1  colab      -> origin/colab
#    30b9a4a..794cea0  main       -> origin/main
# Updating 44ceeff..886c6d1
# Fast-forward
#  sample_hunter/pipeline/train.py        | 7 ++++---
#  sample_hunter/pipeline/triplet_loss.py | 2 +-
#  2 files changed, 5 insertions(+), 4 deletions(-)

# %%
# you can run this and click on the link to monitor the progress
# !mkdir /content/runs
# !tensorboard --logdir /content/runs/

# %%
HF_TOKEN = userdata.get("HF_TOKEN")

# !uv run python3 -m sample_hunter.pipeline.train \
--repo-id samplr/audio-obfuscation \
--out /content/test.pth \
--token $HF_TOKEN \
--tensorboard "batch" \
--log-dir /content/runs
--num-epochs 1
# Out:
# Resolving data files: 100% 84/84 [00:00<00:00, 218.57it/s]
# Resolving data files: 100% 28/28 [00:00<00:00, 190650.18it/s]
# Resolving data files: 100% 84/84 [00:00<00:00, 34783.45it/s]
# Resolving data files: 100% 28/28 [00:00<00:00, 63550.06it/s]
# Resolving data files: 100% 84/84 [00:00<00:00, 169303.96it/s]
# Resolving data files: 100% 28/28 [00:00<00:00, 144988.29it/s]
# Resolving data files: 100% 84/84 [00:00<00:00, 176868.24it/s]
# Resolving data files: 100% 28/28 [00:00<00:00, 213528.20it/s]
# Epoch 1
# Training epoch...: 385it [1:42:07, 15.92s/it]
# object address  : 0x79feb5976f80
# object refcount : 3
# object type     : 0x79fff2293b78
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
